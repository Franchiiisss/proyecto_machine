# %% [markdown]
# # 3. Clustering: Construcción de Personas Cinéfilas
#
# **Objetivo**: Aplicar y comparar algoritmos de clustering (K-Means, GMM, Spectral) sobre embeddings de usuarios para identificar personas cinéfilas.

# %% [markdown]
# ## 3.1 Importación de Librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans, SpectralClustering, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.stats import entropy
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

print('Librerías importadas correctamente')
# Out:
# ✓ Librerías importadas correctamente

# %% [markdown]
# ## 3.2 Carga de Datos Procesados

# %%
# Cargar datos procesados del notebook anterior
user_features = pd.read_csv('data_processed/user_features.csv')
movie_features = pd.read_csv('data_processed/movie_features.csv')
data_final = pd.read_csv('data_processed/data_final.csv')

print('='*60)
print('DATOS CARGADOS')
print('='*60)
print(f'User features: {user_features.shape}')
print(f'Movie features: {movie_features.shape}')
print(f'Data final: {data_final.shape}')
# Out:
# ...
# DATOS CARGADOS
# ...
# User features: (943, 223)
# Movie features: (1682, 221)
# Data final: (100000, 464)
